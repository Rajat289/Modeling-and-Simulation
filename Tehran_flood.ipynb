# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajat289/Modeling-and-Simulation/blob/main/Tehran_flood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Replace with your repo URL
# !git clone https://github.com/Rajat289/Modeling-and-Simulation.git
# Out:
# fatal: destination path 'Modeling-and-Simulation' already exists and is not an empty directory.

# %%
# %cd Modeling-and-Simulation
# Out:
# /content/Modeling-and-Simulation
